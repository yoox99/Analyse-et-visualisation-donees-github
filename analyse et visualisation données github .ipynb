# %%
import pandas as pd
df = pd.read_csv('trs_repos.csv')
df.drop('Unnamed: 0', axis=1, inplace=True)
df['created_at']=pd.to_datetime(df['created_at']).dt.strftime('%Y-%m')
df
# Out:
#                      name                                             url  \
# 0                 notflix           https://github.com/Bugswriter/notflix
# 1                  netspy             https://github.com/shmilylty/netspy
# 2                ProxiTok          https://github.com/pablouser1/ProxiTok
# 3           heirline.nvim        https://github.com/rebelot/heirline.nvim
# 4                  jerboa            https://github.com/dessalines/jerboa
# ...                   ...                                             ...
# 42173          EspUsbHost    https://github.com/tanakamasayuki/EspUsbHost
# 42174  CS-Beacon-Notifier  https://github.com/lynxbinz/CS-Beacon-Notifier
# 42175           notebooks              https://github.com/dmarx/notebooks
# 42176            violetit                https://github.com/nogw/violetit
# 42177       silent-killer    https://github.com/TzviLederer/silent-killer
#
#                                              description  stars created_at  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42178 entries, 0 to 42177
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         42178 non-null  object
#  1   url          42178 non-null  object
#  2   description  42178 non-null  object
#  3   stars        42178 non-null  int64
#  4   created_at   42178 non-null  object
#  5   language     42178 non-null  object
#  6   forks        42178 non-null  int64
#  7   open_issues  42178 non-null  int64
#  8   owner        42178 non-null  object
# dtypes: int64(3), object(6)
# memory usage: 2.9+ MB

# %%
dc = pd.read_csv('contributors.csv')
dc
# Out:
#                username  contributions      repository  \
# 0            Bugswriter             23         notflix
# 1      LamprosPitsillos              2         notflix
# 2             massaynus              1         notflix
# 3      charindithjaindu              1         notflix
# 4               Ocramoi              1         notflix
# ...                 ...            ...             ...
# 68878     ChristianBDev              1  qb-vehicleshop
# 68879         Pride1922              1  qb-vehicleshop
# 68880       SKITTLE6969              1  qb-vehicleshop
# 68881              nogw            326        violetit
# 68882       TzviLederer             14   silent-killer
#
#                                           repository_url
# 0                  https://github.com/Bugswriter/notflix
# 1                  https://github.com/Bugswriter/notflix
# 2                  https://github.com/Bugswriter/notflix
# 3                  https://github.com/Bugswriter/notflix
# ...

# %%
dc.dropna()
dc.drop_duplicates()
# Out:
#                username  contributions      repository  \
# 0            Bugswriter             23         notflix
# 1      LamprosPitsillos              2         notflix
# 2             massaynus              1         notflix
# 3      charindithjaindu              1         notflix
# 4               Ocramoi              1         notflix
# ...                 ...            ...             ...
# 68878     ChristianBDev              1  qb-vehicleshop
# 68879         Pride1922              1  qb-vehicleshop
# 68880       SKITTLE6969              1  qb-vehicleshop
# 68881              nogw            326        violetit
# 68882       TzviLederer             14   silent-killer
#
#                                           repository_url
# 0                  https://github.com/Bugswriter/notflix
# 1                  https://github.com/Bugswriter/notflix
# 2                  https://github.com/Bugswriter/notflix
# 3                  https://github.com/Bugswriter/notflix
# ...

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.models import HoverTool
from bokeh.palettes import Category20
from collections import Counter

# Assuming you have a DataFrame named df with columns like 'name', 'stars', etc.

# Sorting the DataFrame by the number of stars in descending order and selecting the top 30 projects
top_projects = df.nlargest(30, 'stars')

# Extracting the project names and star counts
project_names = top_projects['name'].tolist()
star_counts = top_projects['stars'].tolist()

# Removing duplicates from project_names list
project_names = list(set(project_names))

# Creating the plot
output_notebook()  # If you're working in a Jupyter Notebook, otherwise omit this line

p = figure(width=800, height=400, title="Top 30 Projects by Star Count",
           x_range=project_names, y_range=(0, max(star_counts) + 10))

p.vbar(x=project_names, top=star_counts, width=0.9, color=Category20[20][0])

p.xaxis.axis_label = "Project"
p.yaxis.axis_label = "Star Count"
p.xaxis.major_label_orientation = 1.2

# Adding hover tooltip
hover = HoverTool(tooltips=[("Project", "@x"), ("Star Count", "@top")])
p.add_tools(hover)

show(p)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="ec6451aa-acd6-4e7a-a23b-f19883b6223a">Loading BokehJS ...</span>
#     </div>
# ...
#   <div id="fd176efd-0eb8-4028-a394-659eacf77ed5" data-root-id="p174082" style="display: contents;"></div>

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.models import HoverTool
from bokeh.palettes import Category20
from collections import Counter

# Assuming you have a DataFrame named df with columns like 'name', 'open_issues', etc.

# Sorting the DataFrame by the number of open issues in descending order and selecting the top 30 projects
top_projects = df.nlargest(30, 'open_issues')

# Extracting the project names and open issue counts
project_names = top_projects['name'].tolist()
open_issue_counts = top_projects['open_issues'].tolist()

# Removing duplicates from project_names list
project_names = list(set(project_names))

# Creating the plot
output_notebook()  # If you're working in a Jupyter Notebook, otherwise omit this line

p = figure(width=800, height=400, title="Top 30 Projects by Open Issue Count",
           x_range=project_names, y_range=(0, max(open_issue_counts) + 10))

p.vbar(x=project_names, top=open_issue_counts, width=0.9, color=Category20[20][0])

p.xaxis.axis_label = "Project"
p.yaxis.axis_label = "Open Issue Count"
p.xaxis.major_label_orientation = 1.2

# Adding hover tooltip
hover = HoverTool(tooltips=[("Project", "@x"), ("Open Issue Count", "@top")])
p.add_tools(hover)

show(p)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="cc42218a-fd36-4b8a-b0b2-e84cf3992284">Loading BokehJS ...</span>
#     </div>
#   <div id="ff7d8dcf-1f80-41bf-a6af-5f9cd7302c49" data-root-id="p176515" style="display: contents;"></div>

# %%
df['sum'] = df['stars'] + df['forks'] 
df = df.sort_values(by='sum', ascending=False)
repositories = df['name'].head(10)
data = {'repositories': repositories,
        'stars': df['stars'].head(10),
        'forks': df['forks'].head(10)}

p = figure(x_range=repositories, height=500, title="Repository Statistics",
           toolbar_location=None, tools="hover", tooltips="$name @repositories: @$name")

bars = p.vbar_stack(['stars',  'forks'], x='repositories', width=0.9, color=['black','gold'], source=data,
             legend_label=['Stars',  'Forks'])

p.y_range.start = 0
p.x_range.range_padding = 0.1
p.xgrid.grid_line_color = None
p.axis.minor_tick_line_color = None
p.outline_line_color = None
p.legend.location = "top_right"
p.legend.orientation = "vertical"

p.xaxis.major_label_orientation = 45

show(p)
# Out:
#   <div id="b14811c0-cad8-4422-a3f2-1619aa0ab644" data-root-id="p178961" style="display: contents;"></div>

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.models import HoverTool
from bokeh.palettes import Category20
from collections import Counter

# Assuming you have a DataFrame named df with a column named 'language' containing the programming languages

# Extracting the language counts
languages = df['language'].dropna().tolist()
language_counts = Counter(languages)
top_languages = dict(language_counts.most_common(10))
languages, counts = zip(*top_languages.items())

# Creating the plot
output_notebook()  # If you're working in a Jupyter Notebook, otherwise omit this line

p = figure(width=800, height=400, title="Top 10 Programming Languages Count",
           x_range=languages, y_range=(0, max(counts) + 10))

p.scatter(languages, counts, size=10, color=Category20[20][0])

p.xaxis.axis_label = "Programming Languages"
p.yaxis.axis_label = "Count"
p.xaxis.major_label_orientation = 1.2

# Adding hover tooltip
hover = HoverTool(tooltips=[("Language", "@x"), ("Count", "@y")])
p.add_tools(hover)

show(p)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="ef09698e-d7c3-4f6b-9807-79b7605d80f1">Loading BokehJS ...</span>
#     </div>
#   <div id="c9e1e1ca-d6bc-4360-893b-236df71e7d4a" data-root-id="p181456" style="display: contents;"></div>

# %%
st=df[df['language'].isin(df.groupby('language')['name'].count().sort_values(ascending=False).nlargest(5).keys())]
# Assuming your pandas series is stored in a variable called 'series'
df_st = st.groupby(['created_at','language'])['name'].count().reset_index()
df_st['created_at']=df_st['created_at'].astype(str)

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.palettes import Category20
from bokeh.models import HoverTool, Range1d
import pandas as pd
import math

# Assuming you have a DataFrame named df with columns like 'language', 'stars', etc.

# Count the occurrences of each language
language_counts = df['language'].value_counts().reset_index()
language_counts.columns = ['language', 'count']

# Sort the languages by count in descending order and select the top 10
top_languages = language_counts.nlargest(10, 'count')

# Get the unique top languages
languages = top_languages['language'].tolist()

# Filter the DataFrame for the top languages
df_top_languages = df[df['language'].isin(languages)]

# Calculate the total star count for each language
language_star_count = df_top_languages.groupby('language')['stars'].sum().reset_index()

# Sort the languages by star count in descending order
language_star_count = language_star_count.sort_values('stars', ascending=False)

# Creating the plot
output_notebook()  # If you're working in a Jupyter Notebook, otherwise omit this line

p = figure(x_range=languages, y_range=Range1d(0, max(language_star_count['stars']) + 100),
           height=400, title='Top 10 Languages by Star Count', toolbar_location=None, tools='')

# Set the color palette
colors = Category20[10]

# Plot the bar chart with different colors for each language
p.vbar(x=languages, top=language_star_count['stars'], width=0.8, color=colors[:len(languages)])

p.xaxis.axis_label = 'Language'
p.yaxis.axis_label = 'Star Count'
p.xaxis.major_label_orientation = "vertical"

# Add a hover tool to display exact star count
hover = HoverTool(tooltips=[("Star Count", "@top")])
p.add_tools(hover)

show(p)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="fd6c83d3-cd0b-4432-b89e-7181490b8428">Loading BokehJS ...</span>
#     </div>
#   <div id="e3ebaa3c-ef7a-4c57-a035-b35ebca891b3" data-root-id="p183933" style="display: contents;"></div>

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.palettes import Category20b
from bokeh.models import HoverTool, Range1d
import pandas as pd
import math

# Assuming you have a DataFrame named df with columns like 'language', 'open_issues', etc.

# Count the occurrences of each language
language_counts = df['language'].value_counts().reset_index()
language_counts.columns = ['language', 'count']

# Sort the languages by count in descending order and select the top 10
top_languages = language_counts.nlargest(10, 'count')

# Get the unique top languages
languages = top_languages['language'].tolist()

# Filter the DataFrame for the top languages
df_top_languages = df[df['language'].isin(languages)]

# Calculate the total open issues count for each language
language_open_issues_count = df_top_languages.groupby('language')['open_issues'].sum().reset_index()

# Sort the languages by open issues count in descending order
language_open_issues_count = language_open_issues_count.sort_values('open_issues', ascending=False)

# Creating the plot
output_notebook()  # If you're working in a Jupyter Notebook, otherwise omit this line

p = figure(x_range=languages, y_range=Range1d(0, max(language_open_issues_count['open_issues']) + 100),
           height=400, title='Top 10 Languages by Open Issues Count', toolbar_location=None, tools='')

# Set the color palette
colors = Category20b[10]

# Plot the bar chart with different colors for each language
p.vbar(x=languages, top=language_open_issues_count['open_issues'], width=0.8, color=colors[:len(languages)])

p.xaxis.axis_label = 'Language'
p.yaxis.axis_label = 'Open Issues Count'
p.xaxis.major_label_orientation = "vertical"

# Add a hover tool to display exact open issues count
hover = HoverTool(tooltips=[("Open Issues Count", "@top")])
p.add_tools(hover)

show(p)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="a2ab012f-8dac-453e-b74b-992482747de6">Loading BokehJS ...</span>
#     </div>
#   <div id="d3ca144a-55ea-4942-a51d-6ed1c5e123dc" data-root-id="p186403" style="display: contents;"></div>

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.palettes import Category20
from bokeh.models import HoverTool, Range1d
import pandas as pd
import math

# Assuming you have a DataFrame named df with columns like 'language', 'forks', etc.

# Count the occurrences of each language
language_counts = df['language'].value_counts().reset_index()
language_counts.columns = ['language', 'count']

# Sort the languages by count in descending order and select the top 10
top_languages = language_counts.nlargest(10, 'count')

# Get the unique top languages
languages = top_languages['language'].tolist()

# Filter the DataFrame for the top languages
df_top_languages = df[df['language'].isin(languages)]

# Calculate the total fork count for each language
language_fork_count = df_top_languages.groupby('language')['forks'].sum().reset_index()

# Sort the languages by fork count in descending order
language_fork_count = language_fork_count.sort_values('forks', ascending=False)

# Creating the plot
output_notebook()  # If you're working in a Jupyter Notebook, otherwise omit this line

p = figure(x_range=languages, y_range=Range1d(0, max(language_fork_count['forks']) + 100),
           height=400, title='Top 10 Languages by Fork Count', toolbar_location=None, tools='')

# Set the color palette
colors = Category20[15]

# Plot the bar chart with different colors for each language
p.vbar(x=languages, top=language_fork_count['forks'], width=0.8, color=colors[:len(languages)])

p.xaxis.axis_label = 'Language'
p.yaxis.axis_label = 'Fork Count'
p.xaxis.major_label_orientation = "vertical"

# Add a hover tool to display exact fork count
hover = HoverTool(tooltips=[("Fork Count", "@top")])
p.add_tools(hover)

show(p)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="f9e39528-8131-4f71-a5b1-a8a19a845ac0">Loading BokehJS ...</span>
#     </div>
#   <div id="ce4ed998-108e-4fc2-985d-3cd0e7c9505c" data-root-id="p188885" style="display: contents;"></div>

# %%
from bokeh.palettes import Category10
from bokeh.models import HoverTool

# Assuming your pandas series is stored in a variable called 'series'
df_st = st.groupby(['created_at', 'language'])['name'].count().reset_index()
df_st['created_at'] = df_st['created_at'].astype(str)

# Configure Bokeh to output the plot in the Jupyter Notebook
output_notebook()

# Create a color palette for different technologies/languages
colors = Category10[10]

# Create the line plot using Bokeh
p = figure(title='Evaluation of Technologies/Languages by Time',
           x_axis_label='Period',
           y_axis_label='Number of Repos',
           x_range=df_st['created_at'].unique())

# Loop through each technology and add a line glyph to the plot
for i, technology in enumerate(df_st['language'].unique()):
    tech_df = df_st[df_st['language'] == technology]
    line = p.line(x='created_at', y='name', source=tech_df,
                  legend_label=technology, line_color=colors[i % len(colors)])

    # Add hover tool with tooltips to the line glyph
    hover = HoverTool(renderers=[line], tooltips=[('Language', technology), ('Count', '@name')])
    p.add_tools(hover)

# Rotate x-axis labels for better visibility
p.xaxis.major_label_orientation = 45

# Display the plot
show(p)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="fe1a237a-a2ef-4767-acf7-b33bbfc0bfbe">Loading BokehJS ...</span>
#     </div>
#   <div id="f39abe93-286a-4fa0-94fb-71660fb56cf6" data-root-id="p191378" style="display: contents;"></div>

# %%
from bokeh.plotting import figure, output_notebook, show
from bokeh.models import ColumnDataSource, HoverTool
from bokeh.palettes import Category20
from bokeh.transform import dodge

# Enable output to Jupyter Notebook
output_notebook()

# Group the DataFrame by username and sum the contributions
grouped_contributors = dc.groupby('username')['contributions'].sum().reset_index()

# Filter out usernames that contain 'bot' or 'actions'
filtered_contributors = grouped_contributors[~grouped_contributors['username'].str.contains('bot|actions')]

# Get the top contributors from the filtered DataFrame
top_contributors = filtered_contributors.nlargest(20, 'contributions')

# Prepare the data for plotting
data = {
    'username': top_contributors['username'],
    'contributions': top_contributors['contributions'],
    'repository': top_contributors['username']  # Placeholder for repository name
}

# Create a ColumnDataSource object
source = ColumnDataSource(data)

# Define the figure and plot the bar chart
p = figure(x_range=data['username'], height=400, title='Top Contributors', toolbar_location=None, tools='')

# Add hover tool with tooltips
hover = HoverTool(tooltips=[("Username", "@username"), ("Contributions", "@contributions")])
p.add_tools(hover)

p.vbar(x=dodge('username', 0, range=p.x_range), top='contributions', width=0.6, source=source, color='black', legend_label='Contributions')

# Customize the plot
p.xgrid.grid_line_color = None
p.y_range.start = 0
p.xaxis.major_label_orientation = 1.2
p.legend.location = 'top_right'
p.legend.label_text_font_size = '8pt'
 
# Show the plot
show(p)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="dab677d8-a19b-4387-9283-6391615b3aae">Loading BokehJS ...</span>
#     </div>
#   <div id="d844be09-2285-4207-91d1-fa8013f9aec7" data-root-id="p281704" style="display: contents;"></div>
